# %%
# %cd /kaggle/working
# !rm -rf /kaggle/working/YOLAVIS
# !git clone --depth 1 --branch main https://github.com/duy12i1i7/YOLAVIS.git /kaggle/working/YOLAVIS
# Out:
# /kaggle/working
# Cloning into '/kaggle/working/YOLAVIS'...
# remote: Enumerating objects: 965, done.
# remote: Counting objects: 100% (965/965), done.
# remote: Compressing objects: 100% (754/754), done.
# remote: Total 965 (delta 196), reused 956 (delta 196), pack-reused 0 (from 0)
# Receiving objects: 100% (965/965), 2.26 MiB | 14.18 MiB/s, done.
# Resolving deltas: 100% (196/196), done.

# %%
# %cd /kaggle/working/YOLAVIS/ultralytics
# !pip install -q -e .
# Out:
# /kaggle/working/YOLAVIS/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
# !mkdir -p /kaggle/working/YOLAVIS/ultralytics/ultralytics/assets
# !wget -q -O /kaggle/working/YOLAVIS/ultralytics/ultralytics/assets/bus.jpg \
  https://raw.githubusercontent.com/ultralytics/ultralytics/main/ultralytics/assets/bus.jpg

# %%
# !yolo detect train \
  model=/kaggle/working/YOLAVIS/ultralytics/ultralytics/cfg/models/26/yolo26-nova.yaml \
  data=VisDrone.yaml \
  epochs=1000 imgsz=640 batch=32 workers=8 device=0,1 \
  project=/kaggle/working/runs name=nova_kaggle
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
#                                                       CUDA:1 (Tesla T4, 14913MiB)
# ...
